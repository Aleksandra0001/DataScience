# %% [markdown]
# <a href="https://colab.research.google.com/github/Aleksandra0001/DataScience/blob/main/HW3_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Третья часть

# %% [markdown]
# В [таблице](https://goit.global/textbooks/python/data-science-xf8b2g/v1/docs/module-03/hw) приведены данные о взаимонезависимых доходностях трех акций: A, B, C.
#
# Постройте линии регрессии, с помощью функции regplot, зависимости доходности одной акции от другой. Всего три графика. Выберите пару акций которые наименее зависимы в доходностях от друг друга.

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
url='https://textbook.edu.goit.global/python/data-science-xf8b2g-pwa/v1/uk/docs/module-03/hw'
data=pd.read_html(url)[0]
data
# Out:
#    Момент наблюдения  Доходность A, %  Доходность B, %  Доходность C, %
# 0                  1               25                0               10
# 1                  2              -10               15               25
# 2                  3               10               -5              -15
# 3                  4                5                5               -5
# 4                  5               35               20               -5
# 5                  6               13               25               15

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 6))
fig.suptitle('Зависимость доходности акций', fontsize=20, color='green', weight='bold', y=1.02)

sns.regplot(x="Доходность A, %", y="Доходность B, %", color='blue', data=data, ax=axes[0]).set(title='Зависимость доходности A, B');
sns.regplot(x="Доходность A, %", y="Доходность C, %", color='red', data=data, ax=axes[1]).set(title='Зависимость доходности A, C');
sns.regplot(x="Доходность B, %", y="Доходность C, %", color='green', data=data, ax=axes[2]).set(title='Зависимость доходности B, C');
plt.show()

# %%
sns.set(rc={'figure.figsize':(15,9)})
sns.regplot(x=data['Доходность A, %'], y=data['Доходность B, %'], data=data, label='Доходность A, % to Доходность C, %', color='blue')
sns.regplot(x=data['Доходность B, %'], y=data['Доходность C, %'], data=data, label='Доходность B, % to Доходность C, %', color='green')
sns.regplot(x=data['Доходность A, %'], y=data['Доходность C, %'], data=data, label='Доходность A, % to Доходность C, %',color='red');

# %%
f = plt.figure(figsize=(22,10))
styles={'family': 'serif',
        'color':  'darkred',
        'weight': 'bold',
        'size': 18,
        }
plt.matshow(data.corr().abs(),fignum=f.number)
plt.xticks(range(data.select_dtypes(['number']).shape[1]), data.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(data.select_dtypes(['number']).shape[1]), data.select_dtypes(['number']).columns, fontsize=14)
cb=plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation matrix', y=1.2, fontdict=styles);
